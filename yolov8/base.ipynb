# %%
import ultralytics

# %%
ultralytics.__version__
# Out:
# '8.1.37'

# %%
# !pip install tracker
# Out:
# Requirement already satisfied: tracker in /home/varun/miniconda3/lib/python3.11/site-packages (0.1.1)

# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from tracker import*
import pickle
import time

# %%
class_list = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 
              'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
down = {}
up = {}
counter_down = []
counter_up = []

red_line_y = 198
blue_line_y = 268
offset = 6

# %%
with open('cached_model.pkl','rb') as f:
    model = pickle.load(f)

# %%
cap=cv2.VideoCapture('highway_mini.mp4')

while True:
    ret, frame = cap.read()
    if not ret:
        break
    count += 1
    # if count % 2 != 0:
    #     continue
    frame = cv2.resize(frame, (1020, 500))

    results = model.predict(frame)
    a = results[0].boxes.data
    a = a.detach().cpu().numpy()
    px = pd.DataFrame(a).astype("float")
    list = []

    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]
        if 'car' in c:
            list.append([x1, y1, x2, y2])
    bbox_id = tracker.update(list)

    for bbox in bbox_id:
        x3, y3, x4, y4, id = bbox
        cx = int(x3 + x4) // 2
        cy = int(y3 + y4) // 2

        if red_line_y<(cy+offset) and red_line_y > (cy-offset):
           down[id]=time.time()   # current time when vehichle touch the first line
        if id in down:
          
           if blue_line_y<(cy+offset) and blue_line_y > (cy-offset):
             elapsed_time=time.time() - down[id]  # current time when vehicle touch the second line. Also we a re minusing the previous time ( current time of line 1)
             if counter_down.count(id)==0:
                counter_down.append(id)
                distance = 10 # meters 
                a_speed_ms = distance / elapsed_time
                a_speed_kh = a_speed_ms * 3.6  # this will give kilometers per hour for each vehicle. This is the condition for going downside
                cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
                cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)  # Draw bounding box
                cv2.putText(frame,str(id),(x3,y3),cv2.FONT_HERSHEY_COMPLEX,0.6,(255,255,255),1)
                cv2.putText(frame,str(int(a_speed_kh))+'Km/h',(x4,y4 ),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,255,255),2)

                
        #####going UP blue line#####     
        if blue_line_y<(cy+offset) and blue_line_y > (cy-offset):
           up[id]=time.time()
        if id in up:

           if red_line_y<(cy+offset) and red_line_y > (cy-offset):
             elapsed1_time=time.time() - up[id]
             # formula of speed= distance/time 
             if counter_up.count(id)==0:
                counter_up.append(id)      
                distance1 = 10 # meters  (Distance between the 2 lines is 10 meters )
                a_speed_ms1 = distance1 / elapsed1_time
                a_speed_kh1 = a_speed_ms1 * 3.6
                cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
                cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)  # Draw bounding box
                cv2.putText(frame,str(id),(x3,y3),cv2.FONT_HERSHEY_COMPLEX,0.6,(255,255,255),1)
                cv2.putText(frame,str(int(a_speed_kh1))+'Km/h',(x4,y4),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,255,255),2)



    
    text_color = (0, 0, 0)  # Black color for text
    yellow_color = (0, 255, 255)  # Yellow color for background
    red_color = (0, 0, 255)  # Red color for lines
    blue_color = (255, 0, 0)  # Blue color for lines

    cv2.rectangle(frame, (0, 0), (250, 90), yellow_color, -1)

    cv2.line(frame, (172, 198), (774, 198), red_color, 2)
    cv2.putText(frame, ('Red Line'), (172, 198), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

    cv2.line(frame, (8, 268), (927, 268), blue_color, 2)
    cv2.putText(frame, ('Blue Line'), (8, 268), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

    cv2.putText(frame, ('Going Down - ' + str(len(counter_down))), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)
    cv2.putText(frame, ('Going Up - ' + str(len(counter_up))), (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

    # Save frame
    # frame_filename = f'detected_frames/frame_{count}.jpg'
    # cv2.imwrite(frame_filename, frame)

    # out.write(frame)

    cv2.imshow("frames", frame)
    # if cv2.waitKey(1) & 0xFF == 27:
    if cv2.waitKey(0) & 0xFF == 27:
        break

cap.release()
# out.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 7 cars, 1 bus, 2 trucks, 2.3ms
# Speed: 17.4ms preprocess, 2.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 1 truck, 2.2ms
# Speed: 0.8ms preprocess, 2.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 2 trucks, 4.9ms
# Speed: 0.8ms preprocess, 4.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 2.1ms
# Speed: 0.8ms preprocess, 2.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 6.4ms
# Speed: 2.7ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 3.4ms
# Speed: 1.2ms preprocess, 3.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 2.6ms
# Speed: 1.6ms preprocess, 2.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 6.6ms
# Speed: 0.8ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 6.6ms
# Speed: 0.8ms preprocess, 6.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 5.2ms
# Speed: 2.6ms preprocess, 5.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 3.7ms
# Speed: 0.8ms preprocess, 3.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 2.1ms
# Speed: 0.8ms preprocess, 2.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 5.2ms
# Speed: 0.8ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 6.0ms
# Speed: 2.6ms preprocess, 6.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 3.2ms
# Speed: 0.8ms preprocess, 3.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 4.8ms
# Speed: 1.5ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 3.0ms
# Speed: 0.9ms preprocess, 3.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 4.4ms
# Speed: 2.2ms preprocess, 4.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 2.6ms
# Speed: 1.1ms preprocess, 2.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 2.6ms
# Speed: 0.8ms preprocess, 2.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 5.3ms
# Speed: 1.7ms preprocess, 5.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 4.1ms
# Speed: 2.0ms preprocess, 4.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 3.6ms
# Speed: 1.5ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 3.5ms
# Speed: 1.5ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 4.5ms
# Speed: 1.4ms preprocess, 4.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 4.2ms
# Speed: 1.9ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 3.4ms
# Speed: 1.5ms preprocess, 3.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 2.1ms
# Speed: 1.0ms preprocess, 2.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 7.1ms
# Speed: 2.7ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 3.2ms
# Speed: 1.3ms preprocess, 3.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4.6ms
# Speed: 2.3ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 7.4ms
# Speed: 2.4ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4.6ms
# Speed: 1.3ms preprocess, 4.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4.8ms
# Speed: 2.3ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 2.2ms
# Speed: 0.9ms preprocess, 2.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 6.6ms
# Speed: 2.8ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 4.4ms
# Speed: 1.9ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 3.9ms
# Speed: 2.0ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 2.7ms
# Speed: 0.8ms preprocess, 2.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 3.8ms
# Speed: 0.8ms preprocess, 3.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 7.1ms
# Speed: 2.7ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 8.1ms
# Speed: 0.8ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 8.2ms
# Speed: 1.2ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 6.2ms
# Speed: 2.8ms preprocess, 6.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2.5ms
# Speed: 0.8ms preprocess, 2.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 6.6ms
# Speed: 0.8ms preprocess, 6.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 6.3ms
# Speed: 0.8ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 9.6ms
# Speed: 0.9ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 4.0ms
# Speed: 1.4ms preprocess, 4.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 6.6ms
# Speed: 2.8ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 6.6ms
# Speed: 2.7ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 7.0ms
# Speed: 2.8ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2.2ms
# Speed: 0.8ms preprocess, 2.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 8.2ms
# Speed: 0.8ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 5.5ms
# Speed: 1.6ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3.3ms
# Speed: 1.2ms preprocess, 3.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3.6ms
# Speed: 1.6ms preprocess, 3.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2.7ms
# Speed: 0.9ms preprocess, 2.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3.6ms
# Speed: 1.5ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 7.5ms
# Speed: 2.7ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 5.1ms
# Speed: 1.7ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 5.3ms
# Speed: 1.7ms preprocess, 5.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 4.6ms
# Speed: 2.2ms preprocess, 4.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3.6ms
# Speed: 1.1ms preprocess, 3.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3.2ms
# Speed: 1.2ms preprocess, 3.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 4.1ms
# Speed: 1.7ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3.8ms
# Speed: 1.6ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 5.4ms
# Speed: 1.7ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2.8ms
# Speed: 1.2ms preprocess, 2.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4.4ms
# Speed: 1.9ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 4.1ms
# Speed: 1.5ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 3.1ms
# Speed: 1.3ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 6.3ms
# Speed: 2.7ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3.6ms
# Speed: 0.8ms preprocess, 3.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 2.1ms
# Speed: 0.8ms preprocess, 2.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 6.9ms
# Speed: 2.9ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 4.8ms
# Speed: 2.6ms preprocess, 4.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 3.4ms
# Speed: 1.2ms preprocess, 3.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 6.8ms
# Speed: 0.8ms preprocess, 6.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 5.4ms
# Speed: 0.8ms preprocess, 5.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 7.6ms
# Speed: 2.7ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3.0ms
# Speed: 1.1ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 5.3ms
# Speed: 2.1ms preprocess, 5.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3.3ms
# Speed: 1.4ms preprocess, 3.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 3.4ms
# Speed: 1.4ms preprocess, 3.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4.2ms
# Speed: 1.5ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3.4ms
# Speed: 1.2ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3.9ms
# Speed: 1.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3.7ms
# Speed: 1.6ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3.8ms
# Speed: 1.6ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2.3ms
# Speed: 1.0ms preprocess, 2.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2.1ms
# Speed: 0.8ms preprocess, 2.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4.5ms
# Speed: 1.9ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3.9ms
# Speed: 1.6ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3.9ms
# Speed: 1.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4.6ms
# Speed: 1.6ms preprocess, 4.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3.7ms
# Speed: 1.5ms preprocess, 3.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3.8ms
# Speed: 1.7ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3.4ms
# Speed: 1.4ms preprocess, 3.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2.1ms
# Speed: 0.8ms preprocess, 2.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4.3ms
# Speed: 1.9ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3.6ms
# Speed: 1.3ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4.4ms
# Speed: 1.3ms preprocess, 4.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 6.7ms
# Speed: 2.3ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3.5ms
# Speed: 1.2ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2.1ms
# Speed: 1.0ms preprocess, 2.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2.2ms
# Speed: 0.8ms preprocess, 2.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3.2ms
# Speed: 1.1ms preprocess, 3.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3.2ms
# Speed: 1.2ms preprocess, 3.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 5.3ms
# Speed: 2.6ms preprocess, 5.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3.8ms
# Speed: 1.6ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4.3ms
# Speed: 1.3ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4.6ms
# Speed: 1.5ms preprocess, 4.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 5.5ms
# Speed: 1.8ms preprocess, 5.5ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3.8ms
# Speed: 1.5ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3.1ms
# Speed: 1.2ms preprocess, 3.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3.7ms
# Speed: 1.5ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2.6ms
# Speed: 1.1ms preprocess, 2.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3.5ms
# Speed: 1.5ms preprocess, 3.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 7.2ms
# Speed: 2.6ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4.2ms
# Speed: 2.0ms preprocess, 4.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3.5ms
# Speed: 1.4ms preprocess, 3.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4.5ms
# Speed: 1.5ms preprocess, 4.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2.5ms
# Speed: 0.9ms preprocess, 2.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 6.7ms
# Speed: 2.6ms preprocess, 6.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 7.2ms
# Speed: 0.8ms preprocess, 7.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2.2ms
# Speed: 0.8ms preprocess, 2.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 4.6ms
# Speed: 1.7ms preprocess, 4.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3.8ms
# Speed: 1.3ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4.7ms
# Speed: 2.5ms preprocess, 4.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 4.1ms
# Speed: 1.4ms preprocess, 4.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2.5ms
# Speed: 1.0ms preprocess, 2.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2.2ms
# Speed: 1.4ms preprocess, 2.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 4.0ms
# Speed: 1.7ms preprocess, 4.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4.0ms
# Speed: 1.5ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3.2ms
# Speed: 1.1ms preprocess, 3.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3.6ms
# Speed: 1.3ms preprocess, 3.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4.3ms
# Speed: 1.4ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3.8ms
# Speed: 1.6ms preprocess, 3.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3.6ms
# Speed: 1.5ms preprocess, 3.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3.1ms
# Speed: 0.8ms preprocess, 3.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 8.4ms
# Speed: 2.6ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2.8ms
# Speed: 1.1ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3.4ms
# Speed: 2.1ms preprocess, 3.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4.2ms
# Speed: 1.5ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4.7ms
# Speed: 1.4ms preprocess, 4.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 4.1ms
# Speed: 1.7ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3.6ms
# Speed: 1.4ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 2.8ms
# Speed: 1.4ms preprocess, 2.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 6.0ms
# Speed: 2.3ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3.8ms
# Speed: 1.5ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 5.0ms
# Speed: 2.3ms preprocess, 5.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 2.3ms
# Speed: 1.0ms preprocess, 2.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 3.1ms
# Speed: 1.3ms preprocess, 3.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 4.2ms
# Speed: 1.9ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 1 truck, 4.7ms
# Speed: 1.6ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 4.8ms
# Speed: 1.9ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 2.3ms
# Speed: 1.1ms preprocess, 2.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2.1ms
# Speed: 0.8ms preprocess, 2.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 3.3ms
# Speed: 1.3ms preprocess, 3.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 4.0ms
# Speed: 1.8ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 4.3ms
# Speed: 1.8ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 3.5ms
# Speed: 1.5ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 3.8ms
# Speed: 1.5ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2.2ms
# Speed: 0.8ms preprocess, 2.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 3.6ms
# Speed: 1.5ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 4.2ms
# Speed: 1.3ms preprocess, 4.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 3.9ms
# Speed: 1.4ms preprocess, 3.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 2.4ms
# Speed: 0.9ms preprocess, 2.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 2.1ms
# Speed: 0.8ms preprocess, 2.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 4.4ms
# Speed: 1.9ms preprocess, 4.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 7.4ms
# Speed: 2.4ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2.5ms
# Speed: 0.8ms preprocess, 2.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 6.7ms
# Speed: 2.2ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2.3ms
# Speed: 1.0ms preprocess, 2.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 3.6ms
# Speed: 1.5ms preprocess, 3.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 4.2ms
# Speed: 1.7ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 2.6ms
# Speed: 1.1ms preprocess, 2.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 4.2ms
# Speed: 1.9ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 6.6ms
# Speed: 2.4ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 3.4ms
# Speed: 1.1ms preprocess, 3.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 3.8ms
# Speed: 1.4ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 2.9ms
# Speed: 1.2ms preprocess, 2.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 5.0ms
# Speed: 1.6ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 2.1ms
# Speed: 0.7ms preprocess, 2.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2.1ms
# Speed: 1.5ms preprocess, 2.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 2.3ms
# Speed: 0.9ms preprocess, 2.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2.3ms
# Speed: 0.8ms preprocess, 2.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 4.6ms
# Speed: 2.1ms preprocess, 4.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 3.9ms
# Speed: 1.2ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 4.3ms
# Speed: 1.3ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 3.7ms
# Speed: 1.3ms preprocess, 3.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 3.9ms
# Speed: 1.7ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 3.0ms
# Speed: 1.3ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 6.2ms
# Speed: 2.4ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 3.5ms
# Speed: 1.5ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 3.6ms
# Speed: 1.6ms preprocess, 3.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 4.1ms
# Speed: 1.7ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 3.8ms
# Speed: 1.4ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 7.1ms
# Speed: 3.3ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 3.5ms
# Speed: 1.0ms preprocess, 3.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
